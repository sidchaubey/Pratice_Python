# %% [markdown]
# <a href="https://colab.research.google.com/github/sidchaubey/Pratice_Python/blob/master/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment - 3: Improving Graphs
#
# ## Part 1 - Importing packages and loading data
#
# ##### Import the following libraries:
#
# numpy with an alias name np,<br>
# pandas with an alias name pd,<br>
# matplotlib.pyplot with an alias name plt, and<br>
# seaborn with an alias name sns.<br>

# %%
# Load the libraries with their aliases
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Using the files train.csv and moviesData.csv, peform the following:
#
# <ul>
# <li>Load these file as pandas dataframes and store it in variables named train and movies respectively.</li>
# <li>Print the first ten rows of train and last ten rows of movies.</li>
# </ul>

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10)
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)
movies.drop(columns=["Unnamed: 0"],inplace=True)
# Print the last ten rows of movies
movies.head(10)
# Out:
#                     title    title_type  ...            actor4                actor5
# 0             Filly Brown  Feature Film  ...     Emilio Rivera   Joseph Julian Soria
# 1                The Dish  Feature Film  ...          Tom Long        Genevieve Mooy
# 2     Waiting for Guffman  Feature Film  ...       Eugene Levy           Bob Balaban
# 3    The Age of Innocence  Feature Film  ...  Richard E. Grant          Alec McCowen
# 4             Malevolence  Feature Film  ...     Heather Magee        Richard Glover
# 5             Old Partner   Documentary  ...               NaN                   NaN
# 6               Lady Jane  Feature Film  ...   Jill Bennett II  Helena Bonham Carter
# 7            Mad Dog Time  Feature Film  ...      Ellen Barkin            Diane Lane
# 8  Beauty Is Embarrassing   Documentary  ...   Jonathan Dayton        Cliff Benjamin
# 9    The Snowtown Murders  Feature Film  ...       Craig Coyne         Richard Green
#
# [10 rows x 30 columns]

# %% [markdown]
# # Part 2 - Drawing correlation and heatmap

# %% [markdown]
# ##### Using the correlation matrix, peform the following:
#
# <ul>
# <li>Find the correlation matrix for the movies.</li>
# <li>Draw a heatmap with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.</li>
# <li>Create a mask to remove the duplicate values from the heatmap.</li>
# </ul>

# %%
# Find out the correlation matrix 
moviesCor = movies.corr()
print(moviesCor)
# Draw the heatmap
plt.figure(figsize=(10,5))
sns.heatmap(corr,cmap="summer",annot=True,fmt=".2f",xticklabels='auto',yticklabels='auto',linewidths=0.5);
plt.show()
# Out:
#                  runtime  thtr_rel_year  ...  critics_score  audience_score
# runtime         1.000000      -0.124754  ...       0.169494        0.172237
# thtr_rel_year  -0.124754       1.000000  ...      -0.096445       -0.062610
# thtr_rel_month  0.215274      -0.026465  ...       0.047717        0.034901
# thtr_rel_day    0.033998       0.089811  ...       0.023837        0.033812
# dvd_rel_year   -0.088603       0.655967  ...       0.009554       -0.073794
# dvd_rel_month  -0.036916       0.038498  ...       0.041502        0.070543
# dvd_rel_day     0.021001      -0.014895  ...      -0.024717        0.019294
# imdb_rating     0.261153      -0.040544  ...       0.770764        0.865149
# imdb_num_votes  0.342462       0.152530  ...       0.200657        0.288328
# critics_score   0.169494      -0.096445  ...       1.000000        0.710695
# audience_score  0.172237      -0.062610  ...       0.710695        1.000000
#
# [11 rows x 11 columns]

# %%
# Creating a mask for removing duplicates
plt.figure(figsize=(10,5))
mask = np.zeros_like(moviesCor, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(moviesCor,mask=mask,cmap="summer",annot=True,fmt=".2f",xticklabels='auto',yticklabels='auto',linewidths=0.5);
plt.show()

# %% [markdown]
# # Part 3 - Drawing plots and customizing these
#
# ### Using a histogram, peform the following:
#
# <ul>
# <li> Draw a histogram of all the numeric features in train. Please note that this can be done in a single command.</li>
#
# <li>Find out whether there is any redundant features in train, which can be dro</li>
# </ul>

# %%
# Draw a histogram
a = list(movies)
lst = [] 
def numeric(col):
  for name in col:
    if isinstance(movies[name][0],int) or isinstance(movies[name][0],float):
      lst.append(name)

# %%
numeric(a)
print(lst)
# Out:
# ['runtime', 'dvd_rel_year', 'dvd_rel_month', 'dvd_rel_day', 'imdb_rating']

# %%
for nume in lst:
  plt.hist(movies[nume],color="red")
  plt.xlabel(nume)
  plt.ylabel("count")
  plt.title("Histogram for "+nume)
  plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Find out the redundant features
# Redudant features are

# %% [markdown]
# #### Using a scatter plot, perform the following:
# <ul>
# <li>Draw a scatter plot between between imdb_rating and audience_score, and also fit a regression line.</li>
# <li>Change the color of marker to red, size to 200, transparency to 0.3
# </li>
# </ul>

# %%
# Scatter plot to fit the regression line
sns.regplot(x='imdb_rating',y="audience_score",data=movies,marker="o",color="red");

# %%
# Change marker of the scatter plot
sns.regplot(x='imdb_rating',y="audience_score",data=movies,marker="+",color="red");

# %% [markdown]
# # Using a scatter plot, perform the following:
#
# <ul>
# <li>Draw a scatter plot between between imdb_rating and audience_score, and also fit a regression line.</li>
# <li>Change the color of marker to red, size to 200, transparency to 0.3.
# </li>
# </ul>

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# Use the 'hue' argument to provide a factor variable
plt.figure(figsize=(10,5))
sns.scatterplot(x="petal_length",y="sepal_length",data=df,hue="species",size=100)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %%
sns.set_style("whitegrid");
sns.pairplot(df,hue="species",size=3);
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# # Part 4 - Density Plots

# #### Using density plots, perform the following:
# <ul>
# <li>Load the dataset iris. This has been done for you.
# Draw the density plots for all the features sepal_width, sepal_length, petal_width, and petal_length. You can required to use subplots for plotting all the density plots.
# Try drawing a CDF of these features. There is a blog on medium on how to pl
# </li>
# </ul>

# %%
# library and dataset 
df = sns.load_dataset('iris')

# %%
sns.jointplot(x="sepal_length",y="sepal_width",data=df,kind="kde")
plt.show()

# %%
iris_setosa = df.loc[df["species"] == "setosa"];
iris_virginica = df.loc[df["species"] == "virginica"];
iris_versicolor = df.loc[df["species"] == "versicolor"];
counts, bin_edges = np.histogram(df['petal_length'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
cdf = np.cumsum(pdf)
plt.grid()
plt.plot(bin_edges[1:],pdf);
plt.plot(bin_edges[1:], cdf);
# Out:
# [0.24666667 0.08666667 0.         0.02       0.05333333 0.17333333
#  0.19333333 0.12       0.07333333 0.03333333]

# %%
# Using violin plot, perform the following:
# Load the dataset iris. This has been done for you.
# Draw the density plots of species versus sepal_length.
# Assign each group a color like

# versicolor - green,
# setosa - blue,
# virginica - m

# %%
# Draw the normal violin plots

df_ne = df.drop(columns =["species"]) 
lst = list(df_ne.columns)
for name in lst:
  sns.violinplot(x=df["species"],y=df[name])
  plt.xlabel("Species")
  plt.ylabel(name)
  plt.title(name.title())
  plt.show()

# %%
# Change the color of each group

df_ne = df.drop(columns =["species"]) 
lst = list(df_ne.columns)
for name in lst:
  sns.violinplot(x=df["species"],y=df[name],palette="spring")
  plt.xlabel("Species")
  plt.ylabel(name)
  plt.title(name.title())
  plt.show()

# %%
plt.figure(figsize=(10,10))
g = sns.pairplot(df,hue="species",palette="summer")
g = g.map_offdiag(sns.kdeplot)
